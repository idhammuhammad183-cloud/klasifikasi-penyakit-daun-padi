# %%
st.image(img, width=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-80507668.py in <cell line: 0>()
# ----> 1 st.image(img, width=600)
#
# NameError: name 'st' is not defined

# %%
from google.colab import files
files.download("cnn_penyakit_daun_padi.h5")

# %%
streamlit
tensorflow
numpy
pillow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3056403542.py in <cell line: 0>()
# ----> 1 streamlit
#       2 tensorflow
#       3 numpy
#       4 pillow
#
# NameError: name 'streamlit' is not defined

# %%
import streamlit as st
import tensorflow as tf
import numpy as np
from PIL import Image

# ================================
# KONFIGURASI HALAMAN
# ================================
st.set_page_config(
    page_title="Klasifikasi Penyakit Daun Padi",
    layout="centered"
)

st.title("🌾 Klasifikasi Penyakit Daun Padi")
st.write("Website ini menggunakan model CNN untuk mengklasifikasikan penyakit pada daun padi.")

# ================================
# LOAD MODEL
# ================================
@st.cache_resource
def load_model():
    model = tf.keras.models.load_model("cnn_penyakit_daun_padi.h5")
    return model

model = load_model()

# ================================
# DAFTAR KELAS (HARUS SESUAI DATASET)
# ================================
class_names = [
    "Bacterial leaf blight",
    "Brown spot",
    "Leaf smut"
]

# ================================
# UPLOAD GAMBAR
# ================================
uploaded_file = st.file_uploader(
    "Upload gambar daun padi",
    type=["jpg", "jpeg", "png"]
)

if uploaded_file is not None:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Gambar yang diunggah", use_column_width=True)

    # ================================
    # PREPROCESSING
    # ================================
    img = image.resize((224, 224))
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # ================================
    # PREDIKSI
    # ================================
    predictions = model.predict(img_array)
    confidence = np.max(predictions)
    predicted_class = class_names[np.argmax(predictions)]

    # ================================
    # OUTPUT
    # ================================
    st.subheader("🧪 Hasil Klasifikasi")
    st.write(f"**Prediksi Penyakit :** {predicted_class}")
    st.write(f"**Tingkat Keyakinan :** {confidence * 100:.2f}%")

# %%
project/
│
├── app.py                     ← website utama
├── cnn_penyakit_daun_padi.h5  ← model CNN
├── requirements.txt           ← dependensi
└── README.md (opsional)
# Out:
#   File "/tmp/ipython-input-3654892335.py", line 2
#     │
#     ^
# SyntaxError: invalid character '│' (U+2502)

# %%
from google.colab import files
files.download("cnn_penyakit_daun_padi.h5")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1084592651.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("cnn_penyakit_daun_padi.h5")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: cnn_penyakit_daun_padi.h5

# %%
# !pip install streamlit

# %%
import streamlit as st
import tensorflow as tf
import numpy as np
from PIL import Image

# Load model
model = tf.keras.models.load_model("cnn_penyakit_daun_padi.h5")

# Label kelas
class_names = ['Bacterial Leaf Blight', 'Brown Spot', 'Leaf Smut']

st.set_page_config(page_title="Klasifikasi Penyakit Daun Padi", layout="centered")

st.title("🌾 Klasifikasi Penyakit Daun Padi")
st.write("Aplikasi berbasis CNN untuk mengklasifikasikan penyakit daun padi")

uploaded_file = st.file_uploader("Upload citra daun padi", type=["jpg", "png", "jpeg"])

if uploaded_file is not None:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Citra Daun Padi", use_column_width=True)

    img = image.resize((224, 224))
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_class = class_names[np.argmax(prediction)]
    confidence = np.max(prediction) * 100

    st.subheader("🧠 Hasil Klasifikasi")
    st.write(f"**Penyakit** : {predicted_class}")
    st.write(f"**Tingkat Keyakinan** : {confidence:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2041973434.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import tensorflow as tf
#       3 import numpy as np
#       4 from PIL import Image
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20
)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=20
)

# %%
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]

print(f"Akurasi Training Akhir  : {final_train_acc*100:.2f}%")
print(f"Akurasi Validasi Akhir  : {final_val_acc*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3614239455.py in <cell line: 0>()
# ----> 1 final_train_acc = history.history['accuracy'][-1]
#       2 final_val_acc = history.history['val_accuracy'][-1]
#       3
#       4 print(f"Akurasi Training Akhir  : {final_train_acc*100:.2f}%")
#       5 print(f"Akurasi Validasi Akhir  : {final_val_acc*100:.2f}%")
#
# NameError: name 'history' is not defined

# %%
model.save("cnn_penyakit_daun_padi.h5")

# %%
import os
os.path.exists("/content/rice_leaf_diseases")

# %%
train_data = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224,224),
    batch_size=16
)

val_data = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224,224),
    batch_size=16
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2871222851.py in <cell line: 0>()
# ----> 1 train_data = image_dataset_from_directory(
#       2     DATASET_PATH,
#       3     validation_split=0.2,
#       4     subset="training",
#       5     seed=123,
#
# NameError: name 'image_dataset_from_directory' is not defined

# %%
DATASET_PATH = "/content/rice_leaf_diseases"

# %%
# !ls rice_leaf_diseases

# %%
# !ls

# %%
# !pwd
# Out:
# /content

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

DATASET_PATH = "rice_leaf_diseases"
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

train_data = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_data = image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipython-input-352919679.py in <cell line: 0>()
#       6 BATCH_SIZE = 16
#       7
# ----> 8 train_data = image_dataset_from_directory(
#       9     DATASET_PATH,
#      10     validation_split=0.2,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230     if seed is None:
#     231         seed = np.random.randint(1e6)
# --> 232     image_paths, labels, class_names = dataset_utils.index_directory(
#     233         directory,
#     234         labels,
#
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.save("cnn_penyakit_daun_padi.h5")

# %%
test_loss, test_accuracy = model.evaluate(validation_generator)
print("Akurasi akhir model:", test_accuracy)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Grafik Akurasi Model CNN')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Grafik Loss Model CNN')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(validation_generator)
print("Test Accuracy:", test_accuracy)

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20
)

# %%
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
data_dir = 'rice_leaf_diseases'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20
)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.summary()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Parameter dasar
img_size = (224, 224)
batch_size = 16

dataset_path = "rice_leaf_diseases"

# Data generator + preprocessing
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Data latih
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

# Data validasi
val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# %%
import os

dataset_path = "rice_leaf_diseases"

classes = os.listdir(dataset_path)
print("Kelas penyakit:", classes)

for cls in classes:
    cls_path = os.path.join(dataset_path, cls)
    print(f"{cls}: {len(os.listdir(cls_path))} gambar")

# %%
# !unzip rice_leaf_diseases.zip
# Out:
# Archive:  rice_leaf_diseases.zip
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0365.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0366.jpg
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0367.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0370.jpg
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0372.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0373.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0374.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0375.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0376.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0377.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0378.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0379.JPG
#   inflating: rice_leaf_diseases/Bacterial leaf blight/DSC_0380.JPG
# ...
